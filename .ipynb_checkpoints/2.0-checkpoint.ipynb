# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import data_processing
# %matplotlib inline
# Out:
# /home/torres/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
data = data_processing.load_data(download=False)
new_data = data_processing.convertToOnehot(data)

# prepare training data
new_data = new_data.values.astype(np.float32) # change to numpy array and float32 [pandas to numpy(float 32)]
np.random.shuffle(new_data)
sep = int(0.7*len(new_data))
sep2 = int(0.9*len(new_data))
train_data = new_data[:sep]
validate_data = new_data[sep:sep2]
test_data = new_data[sep2:]

# %%
# build network
tf_input = tf.placeholder(tf.float32, [None, 25], "input")
tfx = tf_input[:, :21]
tfy = tf_input[:, 21:]

tf_is_training = tf.placeholder(tf.bool, None)  # to control dropout when training and testing
l1 = tf.layers.dense(tfx, 128, tf.nn.relu, name="l1")
d1 = tf.layers.dropout(l1, rate=0.5, training=tf_is_training)   # drop out 50% of inputs
l2 = tf.layers.dense(l1, 128, tf.nn.relu, name="l2")
d2 = tf.layers.dropout(l2, rate=0.5, training=tf_is_training)   # drop out 50% of inputs

out = tf.layers.dense(l2, 4, name="l3")
prediction = tf.nn.softmax(out, name="pred")

# logits是没有经过softmax的prediction，tf会自动给你过一层softmax
loss = tf.losses.softmax_cross_entropy(onehot_labels=tfy, logits=out)

# argmax是为了找出tfy中每行数据对应的汽车状态和out中最有可能的汽车状态
# tf.metrics.accuracy(...)[0]和[1]分别是什么？ [https://www.tensorflow.org/api_docs/python/tf/metrics/accuracy]
# ==> accuracy: A Tensor representing the accuracy, the value of total divided by count.
#     update_op: An operation that increments the total and count variables appropriately and whose value matches accuracy.
accuracy = tf.metrics.accuracy(          # return (acc, update_op), and create 2 local variables
    labels=tf.argmax(tfy, axis=1), predictions=tf.argmax(out, axis=1),)[1]

opt = tf.train.GradientDescentOptimizer(learning_rate=0.1)
# opt = tf.train.AdamOptimizer(learning_rate=0.1) # 准确率反而降低了
train_op = opt.minimize(loss)

sess = tf.Session()
sess.run(tf.group(tf.global_variables_initializer(), tf.local_variables_initializer()))

# %%
for t in range(4000):
    # training
    batch_index = np.random.randint(len(train_data), size=32)
    sess.run(train_op, {tf_input: train_data[batch_index]})

    if t % 50 == 0:
        # testing
        acc_, pred_, loss_ = sess.run([accuracy, prediction, loss], {tf_input: validate_data})
        acc2_ = sess.run([accuracy], {tf_input: test_data})
        print("Step: %i" % t,"| Accurate on validate set: %.6f" % acc_,"| Loss: %.2f" % loss_,)
        print("acc on test set:",acc2_[0])
# Out:
# Step: 0 | Accurate on validate set: 0.633911 | Loss: 1.25
# acc on test set: 0.6416185
# Step: 50 | Accurate on validate set: 0.726672 | Loss: 0.45
# acc on test set: 0.74349713
# Step: 100 | Accurate on validate set: 0.782449 | Loss: 0.31
# acc on test set: 0.7909441
# Step: 150 | Accurate on validate set: 0.804239 | Loss: 0.30
# acc on test set: 0.80780345
# Step: 200 | Accurate on validate set: 0.825373 | Loss: 0.23
# acc on test set: 0.8289017
# Step: 250 | Accurate on validate set: 0.842925 | Loss: 0.19
# acc on test set: 0.84609824
# Step: 300 | Accurate on validate set: 0.855491 | Loss: 0.18
# acc on test set: 0.85776216
# Step: 350 | Accurate on validate set: 0.867425 | Loss: 0.15
# acc on test set: 0.8699422
# Step: 400 | Accurate on validate set: 0.877952 | Loss: 0.13
# acc on test set: 0.8805395
# Step: 450 | Accurate on validate set: 0.887506 | Loss: 0.10
# acc on test set: 0.8898844
# Step: 500 | Accurate on validate set: 0.895013 | Loss: 0.11
# acc on test set: 0.8966106
# Step: 550 | Accurate on validate set: 0.901980 | Loss: 0.09
# acc on test set: 0.9037813
# Step: 600 | Accurate on validate set: 0.908081 | Loss: 0.08
# acc on test set: 0.90940416
# Step: 650 | Accurate on validate set: 0.913505 | Loss: 0.07
# acc on test set: 0.9147399
# Step: 700 | Accurate on validate set: 0.917801 | Loss: 0.08
# acc on test set: 0.9188825
# Step: 750 | Accurate on validate set: 0.921552 | Loss: 0.08
# acc on test set: 0.92223626
# Step: 800 | Accurate on validate set: 0.925114 | Loss: 0.06
# acc on test set: 0.92604554
# Step: 850 | Accurate on validate set: 0.928356 | Loss: 0.06
# acc on test set: 0.92911047
# Step: 900 | Accurate on validate set: 0.931561 | Loss: 0.06
# acc on test set: 0.9323091
# Step: 950 | Accurate on validate set: 0.934587 | Loss: 0.05
# acc on test set: 0.93533236
# Step: 1000 | Accurate on validate set: 0.937461 | Loss: 0.06
# acc on test set: 0.93820536
# Step: 1050 | Accurate on validate set: 0.940004 | Loss: 0.05
# acc on test set: 0.94062006
# Step: 1100 | Accurate on validate set: 0.942260 | Loss: 0.05
# acc on test set: 0.94288766
# Step: 1150 | Accurate on validate set: 0.944326 | Loss: 0.04
# acc on test set: 0.94484586
# Step: 1200 | Accurate on validate set: 0.946167 | Loss: 0.04
# acc on test set: 0.9465896
# Step: 1250 | Accurate on validate set: 0.947921 | Loss: 0.03
# acc on test set: 0.9483659
# Step: 1300 | Accurate on validate set: 0.949652 | Loss: 0.03
# acc on test set: 0.95011777
# Step: 1350 | Accurate on validate set: 0.951310 | Loss: 0.03
# acc on test set: 0.9516928
# Step: 1400 | Accurate on validate set: 0.952651 | Loss: 0.04
# acc on test set: 0.9530098
# Step: 1450 | Accurate on validate set: 0.954146 | Loss: 0.03
# acc on test set: 0.9545279
# Step: 1500 | Accurate on validate set: 0.955449 | Loss: 0.03
# acc on test set: 0.9557617
# Step: 1550 | Accurate on validate set: 0.956670 | Loss: 0.03
# acc on test set: 0.95696354
# Step: 1600 | Accurate on validate set: 0.957861 | Loss: 0.03
# acc on test set: 0.95813626
# Step: 1650 | Accurate on validate set: 0.958981 | Loss: 0.03
# acc on test set: 0.9592401
# Step: 1700 | Accurate on validate set: 0.959953 | Loss: 0.03
# acc on test set: 0.9601569
# Step: 1750 | Accurate on validate set: 0.960912 | Loss: 0.02
# acc on test set: 0.96118337
# Step: 1800 | Accurate on validate set: 0.961897 | Loss: 0.02
# acc on test set: 0.9621543
# Step: 1850 | Accurate on validate set: 0.962830 | Loss: 0.02
# acc on test set: 0.9630742
# Step: 1900 | Accurate on validate set: 0.963640 | Loss: 0.03
# acc on test set: 0.9638358
# Step: 1950 | Accurate on validate set: 0.964482 | Loss: 0.02
# acc on test set: 0.96470374
# Step: 2000 | Accurate on validate set: 0.965282 | Loss: 0.02
# acc on test set: 0.96549416
# Step: 2050 | Accurate on validate set: 0.966079 | Loss: 0.02
# acc on test set: 0.9662813
# Step: 2100 | Accurate on validate set: 0.966805 | Loss: 0.02
# acc on test set: 0.96696466
# Step: 2150 | Accurate on validate set: 0.967465 | Loss: 0.02
# acc on test set: 0.96764976
# Step: 2200 | Accurate on validate set: 0.968127 | Loss: 0.02
# acc on test set: 0.96830446
# Step: 2250 | Accurate on validate set: 0.968792 | Loss: 0.02
# acc on test set: 0.9689621
# Step: 2300 | Accurate on validate set: 0.969429 | Loss: 0.02
# acc on test set: 0.9695917
# Step: 2350 | Accurate on validate set: 0.970039 | Loss: 0.02
# acc on test set: 0.9701951
# Step: 2400 | Accurate on validate set: 0.970624 | Loss: 0.02
# acc on test set: 0.9707739
# Step: 2450 | Accurate on validate set: 0.971185 | Loss: 0.02
# acc on test set: 0.97132945
# Step: 2500 | Accurate on validate set: 0.971725 | Loss: 0.01
# acc on test set: 0.9718633
# Step: 2550 | Accurate on validate set: 0.972243 | Loss: 0.01
# acc on test set: 0.9723766
# Step: 2600 | Accurate on validate set: 0.972769 | Loss: 0.01
# acc on test set: 0.9728978
# Step: 2650 | Accurate on validate set: 0.973249 | Loss: 0.02
# acc on test set: 0.97337294
# Step: 2700 | Accurate on validate set: 0.973738 | Loss: 0.01
# acc on test set: 0.97385705
# Step: 2750 | Accurate on validate set: 0.974183 | Loss: 0.02
# acc on test set: 0.9742981
# Step: 2800 | Accurate on validate set: 0.974612 | Loss: 0.01
# acc on test set: 0.97472364
# Step: 2850 | Accurate on validate set: 0.975052 | Loss: 0.01
# acc on test set: 0.97515947
# Step: 2900 | Accurate on validate set: 0.975477 | Loss: 0.01
# acc on test set: 0.9755805
# Step: 2950 | Accurate on validate set: 0.975863 | Loss: 0.01
# acc on test set: 0.9759634
# Step: 3000 | Accurate on validate set: 0.976236 | Loss: 0.01
# acc on test set: 0.97633374
# Step: 3050 | Accurate on validate set: 0.976598 | Loss: 0.01
# acc on test set: 0.97669214
# Step: 3100 | Accurate on validate set: 0.976971 | Loss: 0.01
# acc on test set: 0.9770621
# Step: 3150 | Accurate on validate set: 0.977332 | Loss: 0.01
# acc on test set: 0.9774205
# Step: 3200 | Accurate on validate set: 0.977682 | Loss: 0.01
# acc on test set: 0.9777679
# Step: 3250 | Accurate on validate set: 0.978000 | Loss: 0.01
# acc on test set: 0.97808284
# Step: 3300 | Accurate on validate set: 0.978329 | Loss: 0.01
# acc on test set: 0.97840995
# Step: 3350 | Accurate on validate set: 0.978649 | Loss: 0.01
# acc on test set: 0.97872746
# Step: 3400 | Accurate on validate set: 0.978960 | Loss: 0.01
# acc on test set: 0.9790358
# Step: 3450 | Accurate on validate set: 0.979240 | Loss: 0.01
# acc on test set: 0.9793146
# Step: 3500 | Accurate on validate set: 0.979534 | Loss: 0.01
# acc on test set: 0.979606
# Step: 3550 | Accurate on validate set: 0.979819 | Loss: 0.01
# acc on test set: 0.9798892
# Step: 3600 | Accurate on validate set: 0.980097 | Loss: 0.01
# acc on test set: 0.9801647
# Step: 3650 | Accurate on validate set: 0.980366 | Loss: 0.01
# acc on test set: 0.98043275
# Step: 3700 | Accurate on validate set: 0.980629 | Loss: 0.01
# acc on test set: 0.98069364
# Step: 3750 | Accurate on validate set: 0.980885 | Loss: 0.01
# acc on test set: 0.9809477
# Step: 3800 | Accurate on validate set: 0.981134 | Loss: 0.01
# acc on test set: 0.9811951
# Step: 3850 | Accurate on validate set: 0.981377 | Loss: 0.01
# acc on test set: 0.9814362
# Step: 3900 | Accurate on validate set: 0.981576 | Loss: 0.01
# acc on test set: 0.9816346
# Step: 3950 | Accurate on validate set: 0.981807 | Loss: 0.01
# acc on test set: 0.98186415
